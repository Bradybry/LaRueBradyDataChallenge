# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import sqlite3

# %%
conn = sqlite3.connect('../data/NHTS.db')

# %%
sql = '''select * from Hhpub 
        inner join Perpub on Hhpub.HOUSEID = Perpub.HOUSEID
        join Vehpub on HHpub.HOUSEID = Vehpub.HOUSEID'''

pd.read_sql_query(sql, conn)
# Out:
#          HOUSEID  TRAVDAY  SAMPSTRAT  HOMEOWN  HHSIZE  HHVEHCNT  HHFAMINC  PC  \
# 0       30000007        2          3        1       3         5         7   2
# 1       30000007        2          3        1       3         5         7   2
# 2       30000007        2          3        1       3         5         7   2
# 3       30000007        2          3        1       3         5         7   2
# 4       30000007        2          3        1       3         5         7   2
# 5       30000007        2          3        1       3         5         7   2
# 6       30000007        2          3        1       3         5         7   2
# 7       30000007        2          3        1       3         5         7   2
# 8       30000007        2          3        1       3         5         7   2
# 9       30000007        2          3        1       3         5         7   2
# 10      30000007        2          3        1       3         5         7   2
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a150ac53f26d> in <module>()
# ----> 1 for col in df.columns:
#       2     print(col)
#
# NameError: name 'df' is not defined

# %%
df.describe()

# %%
sex_filtered = df[(df['R_SEX'] == 2) | (df['R_SEX'] == 1)]

# %%
sex_filtered[['R_SEX','NBIKETRP', 'N']].groupby(by='R_SEX').mean()

# %%
df.NBIKETRP.value_counts()

# %%
(sex_filtered.R_SEX == 2).sum() - (sex_filtered.R_SEX == 1).sum()
